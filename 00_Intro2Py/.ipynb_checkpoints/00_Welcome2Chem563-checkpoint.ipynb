# %% [markdown]
# <!-- slide -->
#
# Intro to Stat Mech (Chem 563)
# -----------------------------
#
# <!-- slide -->
#
# ### Course logistics
#
# -   **Communication:**
#     <!-- .element: class="fragment" data-fragment-index="1" -->
#     Canvas-discussion or Slack-chat! Let’s ditch formal emails :) <br>
# -   **Resources:**
#     <!-- .element: class="fragment" data-fragment-index="2" -->
#     1.  Slides.
#     2.  Handwritten notes.
#     3.  Jupyter notebooks.
#
# <img src="https://external-preview.redd.it/T0lzBejhVKa4KUC-NJP2P59NiauxjxCCshNvCrxrblE.jpg?auto=webp&s=c66d3a311e0d25c4e5c48a10b37a2a075d5b0b2f" width="300">
#
#
#
# <!-- slide -->
#
# ### Computational aspects
#
# Just need a working laptop to access HPC!
#
# <img src="https://d2h0cx97tjks2p.cloudfront.net/blogs/wp-content/uploads/sites/2/2017/12/Features-of-python-01.jpg" width="500">
#
#
# - **Language:** Python3.7 - **Simple toy simulations:** build with from
# scratch with python3/numpy/scipy - **Stat Modeling:** PyMC, Seaborn,
# Statsmodels - **MD Simulations:** OpenMM and HOOMD
#
# <!-- slide -->
#
# Why study Stat Mech?
# --------------------
#
# 1.  **Theoretical foundation of complex systems**
#
#     -   How to describe many-body systems?
#         -   Life is inherently unpredictable and complex.
#         -   Therefore probabilistic thinking is the logic of science.
#         -   Statistical physics = science of complexity or large
#             numbers.
#
# <img src="https://i.stack.imgur.com/j46Ct.png" width="400">
#
# <!-- slide -->
#
# Why study Stat Mech?
# --------------------
#
# 1.  **Applications to physics/chemistry/biology:**
#
#     -   Deeper understanding of Thermodynamics and Kinetics.
#     -   Simulations!
#     -   Data Analysis!
#     -   AI, Inference and Machine Learning!
#
#
# <img src="https://villekaila.files.wordpress.com/2011/04/slide11.jpg" width="400">
#
#
#
# <!-- slide -->
#
# Equations for a lifetime!
# -------------------------
#
# 1.  Entropy! Connections with “Thermodynamics” & Information.
#     <!-- .element: class="fragment" data-fragment-index="1" --> $$
#     \boxed{S=\sum_i p_i log p_i \,\,\,\,\,\, S=k_B logW}
#     $$
#
# 2.  Boltzmann distribution!
#     <!-- .element: class="fragment" data-fragment-index="2" --> $$
#     \boxed{p_i \sim e^{-E_i/k_B T}}
#     $$
#
# 3.  Partition function and Free energy!
#     <!-- .element: class="fragment" data-fragment-index="3" --> $$
#     \boxed{Z=\sum_i e^{-E_i/k_B T} \,\,\,\,\,\, F=-k_B T log Z}
#     $$
#
# 4.  Ideas from probability theory: large deviation, central limit.
#     <!-- .element: class="fragment" data-fragment-index="4" --> $$
#     \boxed{p_N(z)\sim e^{-NI(z)} \,\,\,\,\,\,\ p_N(z)\sim e^{-z^2}}
#     $$
#
# 5.  Ising model of phase transitions!
#     <!-- .element: class="fragment" data-fragment-index="5" --> $$
#     \boxed{H=-J s_i s_j +h s_i}
#     $$
#
# <!-- slide -->
#
# What are you interested in?
# ---------------------------
#
# -   Stat Mech?
# -   Connecting quantum to thermo to kinetics?
# -   Biomolecular problems?
# -   AI and machine learning?
# -   Experimental data/image analysis?
#
# <!-- slide -->
#
# Experience using Python,Jupyter,terminal?
# -----------------------------------------
#
# <img src="https://egrowthpartners.com/wp-content/uploads/2019/01/Good-judgment-comes-from-experience__quotes-by-Will-Rogers-43.png" width="300">
#
#
#
# <!-- slide -->
#
# ### HW, Exam and final presentation/project.
#
# -   Lecture Slides + blackboard problem solving.
# -   HW Every week.
# -   At the end of the class pick a project or presentation.
# -   Preferred format: LaTeX/Markdown ideally in jupyter notebooks.
#
# <!-- slide -->
#
# ### Pie Charts for the class: overview
#
# ``` mermaid
# pie
#     "Theory" : 60
#     "Coding" : 25
#     "Problems" : 35
# ```
#
# <!-- slide -->
#
# ### Pie Charts for the class: topics
#
# ``` mermaid
# pie
#     "Prob & Stats" : 20
#     "Num Methods"  : 20
#     "Simulations" : 20
#     "Thermo" : 20
#     "Chem/Bio" : 20
# ```
#
# <!-- slide -->
#
# ### Accessing GitHub and Logging into HPC
#
# 1.  First step is to ssh into cluster:
#
# ``` bash
# ssh yourname@hpc-class.its.iastate.edu
# cd ~/  # this is your home directory
# git clone https://github.com/DPotoyan/Chem563.git
# ```
#
# 1.  After ssh login is scuessful go on and login to JupyterHub
#     [Link4JupyterHub](https://www.hpc.iastate.edu/guides/classroom-hpc-cluster/jupyterhub)
#
# <!-- slide -->
#
# ### **Python3** and **Project Jupyter** and a little bit of **Julia**
#
# -   Learn more about [Project
#     Jupyter](https://jupyter.org/documentation)
#
# -   Learn More about [Python3](https://docs.python.org/3/)
#
# -   Learn More about [Julia](https://julialang.org/)
#
# <!-- slide -->
#
# ### Learning Scientific Python Ecosystem
#
# -   No prior knowledge assumed: We will review the content! Check out
#     the notebooks in our [GitHub](https://github.com/DPotoyan/Chem563)
#
# -   Similar to this 5-day course for scientist at <br> Heidlberg;
#     [Python: programming for
#     scientists](http://wwwstaff.ari.uni-heidelberg.de/rschmidt/pycourse/index.html)
#
# -   Also check out this fantastic, free introductory python book: [Think
#     Python](https://greenteapress.com/wp/think-python/)
